# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy import stats
import json
import csv
import datetime as dt
# import scipy.stats as sts


# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# ()=tuples/cannot change numbers

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in /Users/cooktherook94/opt/anaconda3/lib/python3.8/site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in /Users/cooktherook94/opt/anaconda3/lib/python3.8/site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for c in lat_lngs:
    city = citipy.nearest_city(c[0], c[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 628

# %%
print(cities)
# Out:
# ['taolanaro', 'chuy', 'hobyo', 'umm kaddadah', 'itapaci', 'hobart', 'kapaa', 'flinders', 'sao joao da barra', 'avarua', 'san patricio', 'new norfolk', 'trunovskoye', 'port alfred', 'amahai', 'ushuaia', 'hilo', 'aranzazu', 'hirara', 'betare oya', 'araouane', 'isangel', 'albany', 'beringovskiy', 'lovozero', 'arraial do cabo', 'tuktoyaktuk', 'shirpur', 'hermanus', 'barentsburg', 'nizhneyansk', 'upernavik', 'saleaula', 'saint george', 'munsingen', 'butaritari', 'veraval', 'mar del plata', 'mys shmidta', 'bathsheba', 'east london', 'stromness', 'punta arenas', 'alagoinhas', 'dwarka', 'atuona', 'bredasdorp', 'mamallapuram', 'puerto ayora', 'babusnica', 'ponta do sol', 'ostrovnoy', 'kaitangata', 'aykhal', 'rikitea', 'baikunthpur', 'umm lajj', 'fortuna', 'roma', 'busselton', 'maniitsoq', 'dikson', 'oyama', 'anloga', 'leningradskiy', 'ribeira grande', 'ternate', 'jamestown', 'barrow', 'lebu', 'saint-joseph', 'vaini', 'pouso alegre', 'ahipara', 'sobolevo', 'cape town', 'yar-sale', 'toliary', 'attawapiskat', 'saskylakh', 'leeds', 'svetlyy yar', 'paamiut', 'nikolskoye', 'opunake', 'condado', 'tasiilaq', 'westport', 'avera', 'mataura', 'merauke', 'yellowknife', 'nokaneng', 'carauari', 'sitka', 'saint-philippe', 'illoqqortoormiut', 'provideniya', 'sentyabrskiy', 'torbay', 'kyra', 'esperance', 'mikuni', 'den helder', 'mount gambier', 'palabuhanratu', 'kalemie', 'cortez', 'mazyr', 'waddan', 'airai', 'georgetown', 'halifax', 'utiroa', 'taltal', 'gamboula', 'ugoofaaru', 'matadi', 'vostok', 'cabo san lucas', 'campos altos', 'samusu', 'nizwa', 'zhigansk', 'hithadhoo', 'rincon', 'vila franca do campo', 'vestmannaeyjar', 'tual', 'olavarria', 'teeli', 'badiraguato', 'luangwa', 'los llanos de aridane', 'punta alta', 'asau', 'bambous virieux', 'khatanga', 'katha', 'oudtshoorn', 'qasigiannguit', 'ilinsko-podomskoye', 'marsa matruh', 'omboue', 'broome', 'kursumlija', 'pisco', 'tiksi', 'alofi', 'longyearbyen', 'inndyr', 'beloha', 'nouadhibou', 'dingle', 'fairbanks', 'corinto', 'mandurah', 'fez', 'joshimath', 'raton', 'buchanan', 'kharhial', 'puerto carreno', 'zastron', 'qaanaaq', 'barinas', 'halalo', 'mangit', 'lompoc', 'zhezkazgan', 'mahebourg', 'half moon bay', 'berlevag', 'bengkulu', 'progreso', 'ouadda', 'houma', 'lagoa', 'ust-kuyga', 'faanui', 'mount isa', 'hamilton', 'codrington', 'thompson', 'venado tuerto', 'tessalit', 'nicoya', 'ayan', 'bam', 'deputatskiy', 'pindiga', 'egvekinot', 'coquimbo', 'dakar', 'caluquembe', 'kloulklubed', 'tabou', 'bluff', 'santo antonio do ica', 'victoria', 'bayevo', 'cooma', 'tabiauea', 'faya', 'cidreira', 'vryburg', 'urucara', 'husavik', 'utrera', 'boueni', 'pryazha', 'sirari', 'sabha', 'saint-pierre', 'vorobyevka', 'san quintin', 'ust-kamchatsk', 'knyaze-volkonskoye', 'souillac', 'mrirt', 'necochea', 'cockburn town', 'pala', 'makaryev', 'severo-kurilsk', 'orbetello', 'macusani', 'sao filipe', 'whitehorse', 'karasjok', 'ajdabiya', 'hasaki', 'saint-francois', 'srednekolymsk', 'coffs harbour', 'oltu', 'gizo', 'aktau', 'borogontsy', 'aksarka', 'mahibadhoo', 'haines junction', 'san-pedro', 'geraldton', 'vaitupu', 'iberia', 'batagay-alyta', 'kitimat', 'thano bula khan', 'yirol', 'yol', 'vila', 'kodiak', 'gasa', 'klaksvik', 'pedro carbo', 'luderitz', 'puerto madryn', 'ancud', 'ishikawa', 'wronki', 'hearst', 'grand-santi', 'deer lake', 'kalmunai', 'umzimvubu', 'laguna verde', 'malmyzh', 'tautira', 'port elizabeth', 'semey', 'demyanovo', 'sisimiut', 'vanavara', 'college', 'touros', 'yambio', 'minsk', 'khani', 'corsicana', 'nemuro', 'piacabucu', 'itarema', 'ambilobe', 'lerwick', 'ozgon', 'grand river south east', 'douentza', 'katsuura', 'russell', 'tinskoy', 'dinsor', 'bobonong', 'bumbuna', 'chokurdakh', 'adre', 'cururupu', 'vila velha', 'cherskiy', 'el dorado', 'qaqortoq', 'mayo', 'parczew', 'pevek', 'brainerd', 'south venice', 'lowestoft', 'tongsa', 'kalaleh', 'devils lake', 'sinnamary', 'barbar', 'carnarvon', 'susurluk', 'tanggu', 'olga', 'invermere', 'alugan', 'kavieng', 'vardo', 'donskoye', 'fairview', 'amderma', 'jacarea ...

# %%
units= "imperial"
# unitc="metric"

url= "http://api.openweathermap.org/data/2.5/weather?"
query_url=f"{url}appid={api_key}&units={units}"
# query_url=f"{url}appid={api_key}&q={city}&units={units}"


# query_url=f"{url}appid={api_key}&q={city}&units={unitc}"

# api.openweathermap.org/data/2.5/weather?q={city name},{state code}&appid={API key}

# api.openweathermap.org/data/2.5/weather?q={city name},{country}&appid={API key}

# %%
# cities_prac1=cities[0:5]
# cities_prac1

# %%
# cities_prac=['Denver','Boston','Pietown','Los Angeles','Oregon','Quito','Kampala', 'Padang']
# cities_prac

# %%
cityp=[]
max_temp=[]
lat=[]
lng=[]
humidity=[]
cloudiness=[]
wind_speed=[]
country=[]
date=[]

# %%
# API calls
for city in cities:
    try:
        response = requests.get(f"{query_url}&q={city}").json()
        cityp.append(response['name'])
        max_temp.append(response['main']['temp_max'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
    except (KeyError):
        print("Missing_data")
        
    time.sleep(1)

# City_ID,City,Cloudiness,Country,Date,Humidity,Lat,Lng,Max Temp,Wind Speed
# Out:
# Missing_data
# Missing_data
# Missing_data
# Missing_data
# Missing_data
# Missing_data
# Missing_data
# Missing_data
# Missing_data
# Missing_data
# Missing_data
# Missing_data
# Missing_data
# Missing_data
# Missing_data
# Missing_data
# Missing_data
# Missing_data
# Missing_data
# Missing_data
# Missing_data
# Missing_data
# Missing_data
# Missing_data
# Missing_data
# Missing_data
# Missing_data
# Missing_data
# Missing_data
# Missing_data
# Missing_data
# Missing_data
# Missing_data
# Missing_data
# Missing_data
# Missing_data
# Missing_data
# Missing_data
# Missing_data
# Missing_data
# Missing_data
# Missing_data
# Missing_data
# Missing_data
# Missing_data
# Missing_data
# Missing_data

# %%
cityp
# Out:
# ['Denver',
#  'Boston',
#  'Los Angeles',
#  'Oregon',
#  'Quito',
#  'Kampala',
#  'Padang',
#  'Chui',
#  'Hobyo',
#  'Umm Kaddadah',
#  'Itapaci',
#  'Hobart',
#  'Kapaa',
#  'Flinders',
#  'São João da Barra',
#  'Avarua',
#  'San Patricio',
#  'New Norfolk',
#  'Trunovskoye',
#  'Port Alfred',
#  'Amahai',
#  'Ushuaia',
#  'Hilo',
#  'Aranzazu',
#  'Hirara',
#  'Bétaré Oya',
#  'Araouane',
#  'Isangel',
#  'Albany',
#  'Beringovskiy',
#  'Lovozero',
#  'Arraial do Cabo',
#  'Tuktoyaktuk',
#  'Shirpur',
#  'Hermanus',
#  'Upernavik',
#  'Saint George',
#  'Münsingen',
#  'Butaritari',
#  'Verāval',
#  'Mar del Plata',
#  'Bathsheba',
#  'East London',
#  'Stromness',
#  'Punta Arenas',
#  'Alagoinhas',
#  'Dwārka',
#  'Atuona',
#  'Bredasdorp',
#  'Mahabalipuram',
#  'Puerto Ayora',
#  'Babušnica',
#  'Ponta do Sol',
#  'Ostrovnoy',
#  'Kaitangata',
#  'Aykhal',
#  'Rikitea',
#  'Baikunthpur',
#  'Umluj',
#  'Fortuna',
#  'Rome',
#  'Busselton',
#  'Maniitsoq',
#  'Dikson',
#  'Oyama',
#  'Anloga',
#  'Leningradskiy',
#  'Ribeira Grande',
#  'Ternate',
#  'Jamestown',
#  'Barrow',
#  'Lebu',
#  'Saint-Joseph',
#  'Vaini',
#  'Pouso Alegre',
#  'Ahipara',
#  'Sobolevo',
#  'Cape Town',
#  'Yar-Sale',
#  'Saskylakh',
#  'Leeds',
#  'Svetlyy Yar',
#  'Paamiut',
#  'Nikolskoye',
#  'Opunake',
#  'Condado',
#  'Tasiilaq',
#  'Westport',
#  'Avera',
#  'Mataura',
#  'Merauke',
#  'Yellowknife',
#  'Nokaneng',
#  'Carauari',
#  'Sitka',
#  'Saint-Philippe',
#  'Provideniya',
#  'Torbay',
#  'Kyra',
#  'Esperance',
#  'Mikuni',
#  'Den Helder',
#  'Mount Gambier',
#  'Kalemie',
#  'Cortez',
#  'Mazyr',
#  'Waddān',
#  'Airai',
#  'George Town',
#  'Halifax',
#  'Taltal',
#  'Gamboula',
#  'Ugoofaaru',
#  'Matadi',
#  'Vostok',
#  'Cabo San Lucas',
#  'Campos Altos',
#  'Nizwá',
#  'Zhigansk',
#  'Hithadhoo',
#  'Rincon',
#  'Vila Franca do Campo',
#  'Vestmannaeyjar',
#  'Tual',
#  'Olavarría',
#  'Teeli',
#  'Badiraguato',
#  'Luangwa',
#  'Los Llanos de Aridane',
#  'Punta Alta',
#  'Asău',
#  'Bambous Virieux',
#  'Khatanga',
#  'Oudtshoorn',
#  'Qasigiannguit',
#  'Marsá Maţrūḩ',
#  'Omboué',
#  'Broome',
#  'Kuršumlija',
#  'Pisco',
#  'Tiksi',
#  'Alofi',
#  'Longyearbyen',
#  'Inndyr',
#  'Beloha',
#  'Nouadhibou',
#  'Dingle',
#  'Fairbanks',
#  'Corinth',
#  'Mandurah',
#  'Fes',
#  'Joshīmath',
#  'Raton',
#  'Buchanan',
#  'Kharhiāl',
#  'Puerto Carreño',
#  'Zastron',
#  'Qaanaaq',
#  'Barinas',
#  'Mangit',
#  'Lompoc',
#  'Zhezkazgan',
#  'Mahébourg',
#  'Half Moon Bay',
#  'Berlevåg',
#  'Bengkulu',
#  'Progreso',
#  'Ouadda',
#  'Houma',
#  'Lagoa',
#  'Ust-Kuyga',
#  'Faanui',
#  'Mount Isa',
#  'Hamilton',
#  'Codrington',
#  'Thompson',
#  'Venado Tuerto',
#  'Tessalit',
#  'Nicoya',
#  'Ayan',
#  'Bam',
#  'Deputatsky',
#  'Pindiga',
#  'Egvekinot',
#  'Coquimbo',
#  'Dakar',
#  'Caluquembe',
#  'Kloulklubed',
#  'Tabou',
#  'Bluff',
#  'Santo Antônio do Içá',
#  'Hong Kong',
#  'Bayevo',
#  'Cooma',
#  'Faya',
#  'Cidreira',
#  'Vryburg',
#  'Urucará',
#  'Husavik',
#  'Utrera',
#  'Boueni',
#  'Pryazha',
#  'Sirari',
#  'Sabha',
#  'Saint-Pierre',
#  'Vorobyevka',
#  'San Quintín',
#  'Knyaze-Volkonskoye',
#  'Souillac',
#  'Necochea',
#  'Cockburn Town',
#  'Pala',
#  "Makar'yev",
#  "Severo-Kuril'sk",
#  'Orbetello',
#  'Macusani',
#  'São Filipe',
#  'Whitehorse',
#  'Karasjok',
#  'Ajdabiya',
#  'Hasaki',
#  'Saint-François',
#  'Srednekolymsk',
#  'Coffs Harbour',
#  'Oltu',
#  'Gizo Government Station',
#  'Aktau',
#  'Borogontsy',
#  'Aksarka',
#  'Mahibadhoo',
#  'Haines Junction',
#  'San-Pédro',
#  'Geraldton',
#  'Iberia',
#  'Batagay-Alyta',
#  'Kitimat',
#  'Yol',
#  'Vila',
#  'Saint Paul Harbor',
#  'Gaza',
#  'Klaksvík',
#  'Pedro Carbo',
#  'Lüderitz',
#  'Puerto Madryn',
#  'Ancud',
#  'Ishikawa',
#  'Wronki',
#  'Hearst',
#  'Grand-Santi',
#  'Deer Lake',
#  'Kalmunai',
#  'Laguna Verde',
#  'Malmyzh',
#  'Tautira',
#  'Port Elizabeth',
#  'Semey',
#  "Dem'yanovo",
#  'Sisimiut',
#  'Vanavara',
#  'College',
#  'Touros',
#  'Yambio',
#  'Minsk',
#  'Khani',
#  'Corsicana',
#  'Nemuro',
#  'Piaçabuçu',
#  'Itarema',
#  'Ambilobe',
#  'Lerwick',
#  'Douentza',
#  'Katsuura',
#  'Russell',
#  'Tinskoy',
#  'Bumbuna',
#  'Chokurdakh',
#  'Adré',
#  'Cururupu',
#  'Vila Velha',
#  'Cherskiy',
#  'El Dorado',
#  'Qaqortoq',
#  'Mayo',
#  'Parczew',
#  'Pevek',
#  'Brainerd',
#  'South Venice',
#  'Lowestoft',
#  'Kalāleh',
#  'Devils Lake',
#  'Sinnamary',
#  'Carnarvon',
#  'Susurluk',
#  'Taku',
#  "Ol'ga",
#  'Invermere',
#  'Alugan',
#  'Kavieng',
#  'Vardø',
#  'Donskoye',
#  'Fairview',
#  'Jacareacanga',
#  'Assiut',
#  'Puerto del Rosario',
#  'Ambon City',
#  'Kuusamo',
#  'Ouro Preto do Oeste',
#  'Jahānābād',
#  'Pitimbu',
#  'Chuguyevka',
#  'Anadyr',
#  'Glinde',
#  'Somerset',
#  'Otavi',
#  'Kashin',
#  'Coahuayana Viejo',
#  'Chipinge',
#  'Seymchan',
#  'Baykit',
#  'Narsaq',
#  'Mitsamiouli',
#  'Kāzerūn',
#  'Saint Anthony',
#  'Castro',
#  'Dudinka',
#  'Edéia',
#  'Bartica',
#  'Mange',
#  'Äänekoski',
#  'Port Pirie',
#  'Anáhuac',
#  'Fougamou',
#  'Atasū',
#  'Montepuez',
#  'Koungheul',
#  'Mogadishu',
#  'Norman Wells',
#  'Evensk',
#  'Rauma',
#  'Morondava',
#  'Coyhaique',
#  'Tigzirt',
#  'Labuhan',
#  'Richards Bay',
#  'Broken Hill',
#  "Kuril'sk",
#  'Matagami',
#  'Maraã',
#  'Pangnirtung',
#  'Panguna',
#  'Samarinda',
#  'Antsohihy',
#  'Béboto',
#  'Dzaoudzi',
#  'Naze',
#  'Sambava',
#  'Karakol',
#  'Vincennes',
#  'Leshukonskoye',
#  'Pskov',
#  'La Rioja',
#  'Bambanglipuro',
#  'Sechura',
#  'Iwanai',
#  'Rocha',
#  'Hornepayne',
#  'Teya',
#  'Belmonte',
#  'Mayumba',
#  'Sioux Lookout',
#  'Conceição do Araguaia',
#  'Dekernes',
#  'Clarence Town',
#  'Veinticinco de Mayo',
#  'Smithers',
#  'Oddur',
#  'Mastic Beach',
#  'Ous',
#  'Salta',
#  'Muleba',
#  'Wagar',
#  'Tiarei',
#  'Greenfield',
#  'Onega',
#  'Ilulissat',
#  'Solnechnyy',
#  'Anderson',
#  'Jamūī',
#  'Aklavik',
#  'Matara',
#  'Cairns',
#  'Fort Nelson',
#  'Gamba',
#  'Edson',
#  'Guiratinga',
#  'Ketchikan',
#  'Lázaro Cárdenas',
#  'Priargunsk',
#  'Campoverde',
#  'Abonnema',
#  'Gulu',
#  'Puerto Baquerizo Moreno',
#  'At-Bashi',
#  'Moussoro',
#  'Bethel',
#  'Tura',
#  'Khandyga',
#  'Teyateyaneng',
#  'Marevo',
#  'Biak',
#  'Clyde River',
#  'Ballina',
#  'Røros',
#  'Rørvik',
#  'Lixouri',
#  'Blackwater',
#  'Salalah',
#  'High Level',
#  'Nanortalik',
#  'Gandajika',
#  "Krasnosel'kup",
#  'Havre-St-Pierre',
#  'Osorno',
#  'Padang',
#  'Shubarshi',
#  "Dyat'kovo",
#  'Campos Novos',
#  'Price',
#  'Bāsār',
#  "Ust'-Ishim",
#  'Fortuna Foothills',
#  'Henties Bay',
#  'Wagga Wagga',
#  'Port Said',
#  'Pasaje',
#  'Marzuq',
#  'Bosaso',
#  'Gerāsh',
#  'Vitim',
#  'Lykhivka',
#  'Noumea',
#  'Turaif',
#  'Lethem',
#  'Shimoda',
#  'Narrabri',
#  'Taldan',
#  'Yārāda',
#  'Havelock',
#  'Yelizovo',
#  'Lagos',
#  'Koungou',
#  'Buraidah',
#  'Te Anau',
#  'Kerrobert',
#  'Waingapu',
#  'Boa Vista',
#  'Barra de Tecoanapa',
#  'Guarapari',
#  'Mandera',
#  'Noyabrsk',
#  'Kahului',
#  'Cayenne',
#  'Kailua',
#  'Huarmey',
#  'Dzilam González',
#  'Lata',
#  'Bratsk',
#  'La Unión',
#  'Rawson',
#  'Hailun',
#  'Pouébo',
#  'Bose',
#  'Tūkrah',
#  'Salinópolis',
#  'Kabinda',
#  'Tezu',
#  'Velasco Ibarra',
#  'Martapura',
#  'Acajutla',
#  'Saldanha',
#  'Alyangula',
#  'Khāsh',
#  'Paramonga',
#  'Emerald',
#  'Surin',
#  'Igrim',
#  'Kudahuvadhoo',
#  'Ixtapa',
#  'Dukhovnitskoye',
#  'Grindavik',
#  'Juneau',
#  'Udimskiy',
#  'Talnakh',
#  'Chicama',
#  'Arlit',
#  'Dunedin',
#  'Portland',
#  'Makakilo City',
#  'Constitución',
#  'Hofn',
#  'Bāglung',
#  'Goderich',
#  'Palmer',
#  'Batagay',
#  'Kupang',
#  'Sumbawanga',
#  'Kavaratti',
#  'Bereda',
#  'North Bend',
#  'Iracoubo',
#  'Obo',
#  'Olinda',
#  'Lima',
#  'Prince Rupert',
#  'Fort Morgan',
#  'Orapa',
#  'Changping',
#  'Yeppoon',
#  'Aswān',
#  'Huilong',
#  'Guerrero Negro',
#  'Bilma',
#  'Zaida',
#  'Teguise',
#  'Marawi',
#  'Kargasok',
#  'Taicheng',
#  'Muli',
#  'Aksay',
#  'Saint-Leu',
#  'Santa Maria',
#  'Nizhniy Kuranakh',
#  'Kisi',
#  'Sur',
#  'Puerto Nariño',
#  'Adrar',
#  'Edd',
#  'Harper',
#  'Makkah al Mukarramah',
#  'Kambove',
#  'Oranjestad',
#  'Kaeo',
#  'Rio Grande',
#  'Tame',
#  'Utmanzai',
#  'Pastos Bons',
#  'Poronaysk',
#  'Bykovo',
#  'Yangambi',
#  'Okha',
#  'Kilinochchi',
#  'Kajaani',
#  'Liwale',
#  'Manggar',
#  'Santa Comba',
#  'Pringsewu',
#  'Poum',
#  'Kushiro',
#  'Lagan',
#  'Bandarbeyla',
#  'Iaçu',
#  'Jumla',
#  'Barras',
#  'Opuwo',
#  'Walvis Bay',
#  'Muzhi',
#  'Esim',
#  'Ryōtsu-minato',
#  'Muskegon',
#  'Verkhoyansk',
#  'Wad Medani',
#  'Daru',
#  'Shingū',
#  'Vallenar',
#  'Mabay',
#  'Mehamn',
#  'Son La',
#  'Port Blair',
#  'Bonthe',
#  'Pandan',
#  'Bahía Blanca',
#  'São João Batista',
#  'Ende',
#  'Wukari',
#  'Sungai Penuh',
#  'La Rinconada',
#  'Moose Factory',
#  'Porto Seguro']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# create a data frame from cities, lat, and temp
weather_dict = {
    "City": cityp,
    "Latitude": lat,
    "Longitude": lng,
    "Max_temp": max_temp,
    "Humidity": humidity,
    "Cloudiness": cloudiness, 
    "Wind_speed": wind_speed,
    "Country": country,
    "Date": date
}
weather_data = pd.DataFrame(weather_dict)
weather_data.head(10)
# Out:
#            City  Latitude  Longitude  Max_temp  Humidity  Cloudiness  \
# 0        Denver   39.7392  -104.9847     52.00        21           0
# 1        Boston   42.3584   -71.0598     46.99        87         100
# 2   Los Angeles   34.0522  -118.2437     68.00        52           1
# 3        Oregon   44.0001  -120.5014     55.99        39         100
# 4         Quito   -0.2299   -78.5249     64.40        63          75
# 5       Kampala    0.3163    32.5822     69.80        88          20
# 6        Padang   -0.9492   100.3543     75.20       100          90
# 7          Chui  -33.6971   -53.4616     55.71        80           6
# 8         Hobyo    5.3505    48.5268     86.27        61           3
# 9  Umm Kaddadah   13.6017    26.6876     89.91        11           4
#
#    Wind_speed Country        Date
# 0        1.01      US  1616095856
# 1        5.75      US  1616095937
# 2        5.41      US  1616096055
# 3       13.00      US  1616096228
# 4        8.05      EC  1616096187
# 5        9.22      UG  1616096230
# 6        2.30      ID  1616096232
# 7        4.81      UY  1616139822
# 8       14.43      SO  1616139824
# 9       21.77      SD  1616139719

# %%
weather_data.describe()
# Out:
#          Latitude   Longitude    Max_temp    Humidity  Cloudiness  Wind_speed  \
# count  588.000000  588.000000  588.000000  588.000000  588.000000  588.000000
# mean    19.455242   14.602575   55.903622   70.727891   53.153061    8.034116
# std     33.235766   88.009788   28.086463   22.046198   40.585330    5.504049
# min    -54.800000 -179.166700  -27.810000    8.000000    0.000000    0.290000
# 25%     -7.564125  -62.109150   35.010000   60.000000    3.750000    3.900000
# 50%     21.414450   22.200700   63.910000   75.000000   60.000000    6.910000
# 75%     48.424525   81.097075   78.607500   87.000000   96.250000   10.592500
# max     78.218600  179.316700  106.000000  100.000000  100.000000   32.210000
#
#                Date
# count  5.880000e+02
# mean   1.616140e+09
# std    4.797065e+03
# min    1.616096e+09
# 25%    1.616140e+09
# 50%    1.616140e+09
# 75%    1.616140e+09
# max    1.616141e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

weather_data= weather_data.loc[(weather_data['Max_temp'])<100,:]

weather_data
# Out:
#               City  Latitude  Longitude  Max_temp  Humidity  Cloudiness  \
# 0           Denver   39.7392  -104.9847     52.00        21           0
# 1           Boston   42.3584   -71.0598     46.99        87         100
# 2      Los Angeles   34.0522  -118.2437     68.00        52           1
# 3           Oregon   44.0001  -120.5014     55.99        39         100
# 4            Quito   -0.2299   -78.5249     64.40        63          75
# ..             ...       ...        ...       ...       ...         ...
# 583         Wukari    7.8500     9.7833     83.17        63         100
# 584   Sungai Penuh   -2.0833   101.3833     71.65        93         100
# 585   La Rinconada   37.4873    -5.9826     50.00        53           0
# 586  Moose Factory   51.2585   -80.6094     10.40        67           1
# 587   Porto Seguro  -16.4497   -39.0647     71.60        94          40
#
#      Wind_speed Country        Date
# 0          1.01      US  1616095856
# 1          5.75      US  1616095937
# 2          5.41      US  1616096055
# 3         13.00      US  1616096228
# 4          8.05      EC  1616096187
# ..          ...     ...         ...
# 583        7.92      NG  1616140671
# 584        2.77      ID  1616140672
# 585        9.22      ES  1616140674
# 586       10.36      CA  1616140675
# 587        2.30      BR  1616140437
#
# [585 rows x 9 columns]

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
len(weather_data)
# Out:
# 585

# %%
weather_data.to_csv(output_data_file)

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Latitude"], weather_data["Max_temp"], marker="o")

# Incorporate the other graph properties
plt.title("Latitude vs. Max Temperature(03/19/21)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# # Save the figure
plt.savefig("../output_data/CitylatitudevsMaxTemp.png")

# # Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Create a Scatter Plot for temperature vs latitude
x_values = weather_data['Latitude']
y_values = weather_data['Humidity']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.title("Latitude vs. Humidity(03/19/21)")
plt.ylabel('Humidity(%)')
plt.grid(True)
plt.savefig("../output_data/CitylatitudevsHumidity.png")

plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Latitude"], weather_data["Cloudiness"], marker="o")

# Incorporate the other graph properties
plt.title("Latitude vs. Cloudiness(03/19/21)")
plt.ylabel("Cloudiness(%)")
plt.xlabel("Latitude")
plt.grid(True)

# # Save the figure
plt.savefig("../output_data/CitylatitudevsCloudiness.png")

# # Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Latitude"], weather_data["Wind_speed"], marker="o")

# Incorporate the other graph properties
plt.title("Latitude vs. Wind Speed(03/19/21)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# # Save the figure
plt.savefig("../output_data/CitylatitudevsWindSpeed.png")

# # Show plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# # Use API to determine actual temperature
# response = requests.get(query_url + "Florence").json()
# florence_actual_temp = response['main']['temp']

# print(f"The actual temperature of Florence is {florence_actual_temp}")
weather_data.dtypes
# Out:
# City           object
# Latitude      float64
# Longitude     float64
# Max_temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind_speed    float64
# Country        object
# Date            int64
# dtype: object

# %%
northernhem= weather_data.loc[(weather_data["Latitude"]) > 0, :]
southernhem = weather_data.loc[(weather_data["Latitude"]) < 0, :]
# northernhem.head()
southernhem.head()
# Out:
#        City  Latitude  Longitude  Max_temp  Humidity  Cloudiness  Wind_speed  \
# 4     Quito   -0.2299   -78.5249     64.40        63          75        8.05
# 6    Padang   -0.9492   100.3543     75.20       100          90        2.30
# 7      Chui  -33.6971   -53.4616     55.71        80           6        4.81
# 10  Itapaci  -14.9508   -49.5494     66.92        93         100        1.97
# 11   Hobart  -42.8794   147.3294     69.80        49          20       11.50
#
#    Country        Date
# 4       EC  1616096187
# 6       ID  1616096232
# 7       UY  1616139822
# 10      BR  1616139826
# 11      AU  1616139813

# %% [markdown]
# # Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = northernhem['Latitude']
y_values = northernhem['Max_temp']
northernhem.plot(kind="scatter", x="Latitude", y="Max_temp")
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(10,0),fontsize=15,color="red")
plt.title("Northern Hemisphere - Max Temp vs. Lat. Linear Regression")
plt.xlabel('Latitude')
plt.ylabel('Max Temp.')
print(f"The r-squared is: {rvalue**2}")

plt.savefig("../output_data/NorthernHem-LatitudevsMaxTempLR.png")


plt.show()
# Out:
# The r-squared is: 0.8093109569888682

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southernhem['Latitude']
y_values = southernhem['Max_temp']
southernhem.plot(kind="scatter", x="Latitude", y="Max_temp")
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.plot(x_values,regress_values,"r-")
plt.title("Southern Hemisphere - Max Temp vs. Lat. Linear Regression")
plt.xlabel('Latitude')
plt.ylabel('Max Temp.')
plt.xlim(-60,5)
plt.ylim(40,100)
print(f"The r-squared is: {rvalue**2}")
plt.annotate(line_eq,(-30,47),fontsize=15,color="red")
plt.savefig("../output_data/SouthernHem-LatitudevsMaxTempLR.png")


plt.show()
# Out:
# The r-squared is: 0.2983569921745765

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northernhem['Latitude']
y_values = northernhem['Humidity']
northernhem.plot(kind="scatter", x="Latitude", y="Humidity")
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.plot(x_values,regress_values,"r-")
plt.title("Northern Hemisphere - Humidity(%) vs. Lat. Linear Regression")
plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')
print(f"The r-squared is: {rvalue**2}")
plt.annotate(line_eq,(45,15),fontsize=15,color="red")

plt.savefig("../output_data/NorthernHem-LatitudevsHumidityLR.png")


plt.show()
# Out:
# The r-squared is: 0.13467949154988665

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southernhem['Latitude']
y_values = southernhem['Humidity']
southernhem.plot(kind="scatter", x="Latitude", y="Humidity")
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,18),fontsize=15,color="red")
plt.title("Southern Hemisphere - Humidity(%) vs. Lat. Linear Regression")
plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')
print(f"The r-squared is: {rvalue**2}")
plt.savefig("../output_data/SouthernHem-LatitudevsHumidityLR.png")


plt.show()
# Out:
# The r-squared is: 0.0817975511728138

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northernhem['Latitude']
y_values = northernhem['Cloudiness']
northernhem.plot(kind="scatter", x="Latitude", y="Cloudiness")
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.plot(x_values,regress_values,"r-")
plt.title("Northern Hemisphere - Cloudiness(%) vs. Lat. Linear Regression")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
print(f"The r-squared is: {rvalue**2}")
plt.annotate(line_eq,(5,15),fontsize=15,color="red")
plt.savefig("../output_data/NorthernHem-LatitudevsCloudinessLR.png")


plt.show()
# Out:
# The r-squared is: 0.04065921584452504

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southernhem['Latitude']
y_values = southernhem['Cloudiness']
southernhem.plot(kind="scatter", x="Latitude", y="Cloudiness")
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.plot(x_values,regress_values,"r-")
plt.title("Southern Hemisphere - Cloudiness(%) vs. Lat. Linear Regression")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
print(f"The r-squared is: {rvalue**2}")
plt.annotate(line_eq,(-50,50),fontsize=15,color="red")
plt.savefig("../output_data/SouthernHem-LatitudevsCloudinessLR.png")


plt.show()
# Out:
# The r-squared is: 0.19830569680945834

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northernhem['Latitude']
y_values = northernhem['Wind_speed']
northernhem.plot(kind="scatter", x="Latitude", y="Wind_speed")
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.plot(x_values,regress_values,"r-")
# plt.annotate(line_eq,(10,4),fontsize=15,color="red")
plt.title("Northern Hemisphere - Wind Speed(mph) vs. Lat. Linear Regression")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed(mph)')
print(f"The r-squared is: {rvalue**2}")
plt.annotate(line_eq,(5,25),fontsize=15,color="red")
plt.savefig("../output_data/NorthernHem-LatitudevsWindSpeedLR.png")


plt.show()
# Out:
# The r-squared is: 0.013276373537222807

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southernhem['Latitude']
y_values = southernhem['Wind_speed']
southernhem.plot(kind="scatter", x="Latitude", y="Wind_speed")
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.plot(x_values,regress_values,"r-")
# plt.annotate(line_eq,(10,4),fontsize=15,color="red")
plt.title("Northern Hemisphere - Wind Speed(mph) vs. Lat. Linear Regression")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed(mph)')
print(f"The r-squared is: {rvalue**2}")
plt.annotate(line_eq,(-20,20),fontsize=15,color="red")
plt.savefig("../output_data/Southernhem-LatitudevsWindSpeedLR.png")


plt.show()
# Out:
# The r-squared is: 0.10155399184339446
